# %% [markdown]
# ## Dicionário de dados

# %%
import pandas as pd

# %%
sleep = pd.read_csv("../data/raw/Sleep_Efficiency.csv")
sleep.head()
# Out:
#    Unnamed: 0  ID  Age  Gender              Bedtime          Wakeup time  \
# 0           0   1   65  Female  2021-03-06 01:00:00  2021-03-06 07:00:00
# 1           1   2   69    Male  2021-12-05 02:00:00  2021-12-05 09:00:00
# 2           2   3   40  Female  2021-05-25 21:30:00  2021-05-25 05:30:00
# 3           3   4   40  Female  2021-11-03 02:30:00  2021-11-03 08:30:00
# 4           4   5   57    Male  2021-03-13 01:00:00  2021-03-13 09:00:00
#
#    Sleep duration  Sleep efficiency  REM sleep percentage  \
# 0             6.0              0.88                    18
# 1             7.0              0.66                    19
# 2             8.0              0.89                    20
# 3             6.0              0.51                    23
# 4             8.0              0.76                    27
#
#    Deep sleep percentage  Light sleep percentage  Awakenings  \
# 0                     70                      12         0.0
# ...

# %%
sleep = pd.read_csv("../data/raw/Sleep_Efficiency.csv")

# %%
sleep = sleep.to_csv("../data/raw/Sleep_Efficiency.csv")

# %%
# Dicionário de dados
data_dictionary = pd.DataFrame([
    {
        "variavel":"ID",
        "descricao":"Identificador único do sujeito",
        "tipo":"Quantitativo",
        "subtipo":"Discreta"
    },
    {
        "variavel":"Age",
        "descricao":"Idade do sujeito",
        "tipo":"Quantitativo",
        "subtipo":"Discreta"
        
    },
    {
        "variavel":"Gender",
        "descricao":"Gênero do sujeito",
        "tipo":"Qualitativo",
        "subtipo":"Nominal"
    },
    {
        "variavel":"Bedtime",
        "descricao":"Hora em que o sujeito vai para a cama",
        "tipo":"Cíclica",
        "subtipo":"Cíclica"
    },
    {
        "variavel":"Wakeup time",
        "descricao":"Hora em que o sujeito acorda",
        "tipo":"Cíclica",
        "subtipo":"Cíclica"
    },
    {
        "variavel":"Sleep duration",
        "descricao":"Duração total do sono em horas",
        "tipo":"Cíclica",
        "subtipo":"Cíclica"
    },
    {
        "variavel":"Sleep efficiency",
        "descricao":"Representa a porcentagem de tempo que o sujeito passou dormindo enquanto estava na cama",
        "tipo":"Quantitativo",
        "subtipo":"Contínua"
    },
    {
        "variavel":"REM sleep percentage",
        "descricao":"Porcentagem do tempo total de sono que foi gasto no estágio REM, fase do sono associada aos sonhos",
        "tipo":"Quantitativo",
        "subtipo":"Contínua"
    },
    {
        "variavel":"Deep sleep percentage",
        "descricao":"Porcentagem do tempo total de sono que foi gasto no estágio de sono profundo, fase do sono que é mais restauradora",
        "tipo":"Quantitativo",
        "subtipo":"Contínua"
    },
    {
        "variavel":"Light sleep percentage",
        "descricao":"Porcentagem do tempo total de sono que foi gasto no estágio de sono leve, fase do sono mais superficial",
        "tipo":"Quantitativo",
        "subtipo":"Contínua"
    },
    {
        "variavel":"Awakenings",
        "descricao":"Número de vezes que o sujeito acorda durante a noite",
        "tipo":"Quantitativo",
        "subtipo":"Discreta"
    },
    {
        "variavel":"Caffeine consumption",
        "descricao":"Quantidade de cafeína consumida pelo sujeito nas 24 horas anteriores à hora de dormir, registrada em miligramas",
        "tipo":"Quantitativo",
        "subtipo":"Contínua"
    },
    {
        "variavel":"Alcohol consumption",
        "descricao":"Quantidade de álcool consumido pelo sujeito nas 24 horas anteriores à hora de dormir, registrada em mililitros",
        "tipo":"Quantitativo",
        "subtipo":"Contínua"
    },
    {
        "variavel":"Smoking status",
        "descricao":"Status de fumante do sujeito",
        "tipo":"Qualitativo",
        "subtipo":"Nominal"
    },
    {
        "variavel":"Exercise frequency",
        "descricao":"Frequência de exercícios físicos praticados pelo sujeito",
        "tipo":"Quantitativo",
        "subtipo":"Discreta"
    }
    
])

#Salvar dicionário
data_dictionary.to_csv("../data/external/dictionary.csv", index=False)
